# %% [markdown]
# # Kaggle Linter Test Notebook

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Load data - has undefined variable error
df = pd.read_csv('/kaggle/input/data.csv')
print(dataframe.shape)
print(Data_Frame.columns)

# %%
# Function with indentation error
def calculate_stats(values):
    mean_val = np.mean(values)
max_val = np.max(values)
    return mean_val, max_val

# %%
# Duplicate function definitions
def preprocess(data):
    data = data.fillna(0)
    # No return statement

def preprocess(data):
    return data.dropna()

# %%
# Redefined variables
features = df[['col1', 'col2', 'col3']]
target = df['target']

features = df[['col1', 'col2']]

# %% [markdown]
# ## More cells

# %%
# Unclosed brackets
my_list = [1, 2, 3, 4, 5
my_dict = {'a': 1, 'b': 2}
print(my_list)

# %%
# Import issues - importing after usage
result = sklearn_function()
from sklearn.preprocessing import StandardScaler

# %%
# This one is correct
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2)
print(f'Training samples: {len(X_train)}')
